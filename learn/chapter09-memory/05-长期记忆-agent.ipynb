# %% [markdown]
# # 长期记忆-agent
#
# ## 1、在工具中访问长期记忆
#
# ### 1.1 基于InMemoryStore

# %%
from typing import NotRequired

from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

from langchain_core.tools import tool

# 从.env文件中加载环境变量
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="openai",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL")
)

# %%
from langgraph.prebuilt import ToolRuntime
from langchain_core.messages import HumanMessage
from langgraph.store.memory import InMemoryStore
from langchain.agents import create_agent, AgentState

store = InMemoryStore()

# 自定义一个继承于AgentState的类
class CustomState(AgentState):
    user_id : NotRequired[str]

# 保存用户信息到长期记忆中
@tool(parse_docstring=True)
def save_user_info(name : str , runtime : ToolRuntime) -> str:
    """
    将客户信息保存在长期记忆中

    Args:
        name : 用户名
        runtime : 工具的运行时

    Returns:
        str : 保存状态
    """
    namespace = ("users",)
    key = runtime.state["user_id"]
    value = {"name" : name}

    runtime.store.put(namespace, key, value)
    return "saved"


@tool(parse_docstring=True)
def get_user_info(runtime : ToolRuntime) -> str:
    """
    从长期记忆中读取客户的信息

    Args:
        runtime : 工具的运行时

    Returns:
        str : 用户信息
    """
    namespace = ("users",)
    key = runtime.state["user_id"]

    item = runtime.store.get(namespace,key)
    return str(item.value) if item else "unknown"

agent = create_agent(
    model=model,
    tools=[save_user_info,get_user_info],
    store=store,
    state_schema=CustomState,
    system_prompt="用户提及个人信息时，可以使用工具保存用户信息。如果用户询问个人信息时，可以尝试使用工具读取用户信息"
)

print("=" * 30, '-> 第一个会话（线程） <-', "=" * 30)
response1 = agent.invoke({
    "messages": [HumanMessage("你好，很高兴认识你，我是小花")],
    "user_id": "user-1"
})
for msg in response1["messages"]:
    msg.pretty_print()

print("=" * 30, '-> 第二个会话（线程） <-', "=" * 30)
response2 = agent.invoke({
    "messages": [HumanMessage("我是谁")],
    "user_id": "user-1"
})
for msg in response2["messages"]:
    msg.pretty_print()
# Out:
# ============================== -> 第一个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 你好，很高兴认识你，我是小花
# ================================== Ai Message ==================================
#
# 小花你好呀！很高兴认识你！😊
#
# 让我把你的名字记下来，这样以后就不会忘记啦！
# Tool Calls:
#   save_user_info (call_00_MCcICNlWFl2glPUNfji23623)
#  Call ID: call_00_MCcICNlWFl2glPUNfji23623
#   Args:
#     name: 小花
# ================================= Tool Message =================================
# Name: save_user_info
#
# saved
# ================================== Ai Message ==================================
#
# 已经把你的名字"小花"记在我的小本本上啦！📝
#
# 以后有什么需要帮忙的，随时找我就好～有什么我可以为你效劳的吗？😊
# ============================== -> 第二个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 我是谁
# ================================== Ai Message ==================================
#
# 您好！让我查一下您的信息。
# Tool Calls:
#   get_user_info (call_00_K6Uw4BWqufFCnBAAVEaA7040)
#  Call ID: call_00_K6Uw4BWqufFCnBAAVEaA7040
#   Args:
# ================================= Tool Message =================================
# Name: get_user_info
#
# {'name': '小花'}
# ================================== Ai Message ==================================
#
# 我查到您叫 **小花** 🌸 哦！不过目前我只知道您的名字，如果您想告诉我更多信息（比如喜好、需求等），我都可以帮您记下来，方便以后更好地为您服务～ 😊

# %% [markdown]
# ### 1.2 基于PostgresStore

# %%
from langgraph.store.postgres import PostgresStore
from langgraph.prebuilt import ToolRuntime
from langchain_core.messages import HumanMessage
from langgraph.store.memory import InMemoryStore
from langchain.agents import create_agent, AgentState



# 自定义一个继承于AgentState的类
class CustomState(AgentState):
    user_id : NotRequired[str]

# 保存用户信息到长期记忆中
@tool(parse_docstring=True)
def save_user_info(name : str , runtime : ToolRuntime) -> str:
    """
    将客户信息保存在长期记忆中

    Args:
        name : 用户名
        runtime : 工具的运行时

    Returns:
        str : 保存状态
    """
    namespace = ("users",)
    key = runtime.state["user_id"]
    value = {"name" : name}

    runtime.store.put(namespace, key, value)
    return "saved"


@tool(parse_docstring=True)
def get_user_info(runtime : ToolRuntime) -> str:
    """
    从长期记忆中读取客户的信息

    Args:
        runtime : 工具的运行时

    Returns:
        str : 用户信息
    """
    namespace = ("users",)
    key = runtime.state["user_id"]

    item = runtime.store.get(namespace,key)
    return str(item.value) if item else "unknown"

DB_URL = "postgresql://langchain_user:abcd1234@118.195.166.24:5432/langchain_db?sslmode=disable"

with PostgresStore.from_conn_string(DB_URL) as store:
    store.setup()

    agent = create_agent(
        model=model,
        tools=[save_user_info,get_user_info],
        store=store,
        state_schema=CustomState,
        system_prompt="用户提及个人信息时，可以使用工具保存用户信息。如果用户询问个人信息时，可以尝试使用工具读取用户信息"
    )

    print("=" * 30, '-> 第一个会话（线程） <-', "=" * 30)
    response1 = agent.invoke({
        "messages": [HumanMessage("你好，很高兴认识你，我是小花")],
        "user_id": "user-1"
    })
    for msg in response1["messages"]:
        msg.pretty_print()

    print("=" * 30, '-> 第二个会话（线程） <-', "=" * 30)
    response2 = agent.invoke({
        "messages": [HumanMessage("我是谁")],
        "user_id": "user-1"
    })
    for msg in response2["messages"]:
        msg.pretty_print()
# Out:
# ============================== -> 第一个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 你好，很高兴认识你，我是小花
# ================================== Ai Message ==================================
# Tool Calls:
#   save_user_info (call_I8KqpHeBqHXdnomzaHdxZvm0)
#  Call ID: call_I8KqpHeBqHXdnomzaHdxZvm0
#   Args:
#     name: 小花
# ================================= Tool Message =================================
# Name: save_user_info
#
# saved
# ================================== Ai Message ==================================
#
# 你好，小花，很高兴认识你！有什么我可以帮你的吗？
# ============================== -> 第二个会话（线程） <- ==============================
# ================================ Human Message =================================
#
# 我是谁
# ================================== Ai Message ==================================
# Tool Calls:
#   get_user_info (call_rljSYINWoRTuBub9cHxtVDQe)
#  Call ID: call_rljSYINWoRTuBub9cHxtVDQe
#   Args:
# ================================= Tool Message =================================
# Name: get_user_info
#
# {'name': '小花'}
# ================================== Ai Message ==================================
#
# 你是小花。
