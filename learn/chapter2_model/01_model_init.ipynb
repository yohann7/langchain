# %% [markdown]
# # 1.模型专用调用

# %% [markdown]
# ## 1.1.调用DeepSeek官网模型

# %%
import os
from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

response = llm_deepseek.invoke("请帮我写一首关于春天的诗")
print(response)
# Out:
# content='《春行》\n东君行令处，草木自为宾。\n一雨千山醒，风扶绿涨新。\n莺梭穿柳线，燕剪裁云巾。\n莫问春何处，春在踏青人。\n\n注：我的诗作《春行》通过“东君行令”“一雨千山”等意象，展现春天如君王巡行般唤醒万物的磅礴气势。后以“莺梭燕剪”的灵动笔触，勾勒出春色渐浓的细腻过程。尾联“春在踏青人”巧妙点题，将自然春意与人的活动相融，既回应了“寻春”的哲思，又暗合现代人踏青赏春的生活情趣，使传统诗题焕发新意。' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户想要一首关于春天的诗。需要抓住春天的典型意象，比如自然景物、动物、天气变化等，同时要传递出生机勃勃的氛围。可以试试五言绝句这种短小精炼的形式，符合古典诗意。\n\n想到用“东君”指代春神，带出拟人化的感觉。用“莺啼”“蜂喧”表现动物活跃，搭配“绿林”“晴光”突出色彩和温度。“莠芽出腐草”可以展现生命突破凋敝的意象，最后用“野客”与“金樽”形成对比，增加一点哲理意味。\n\n韵脚选择“君”“林”“喧”“樽”，押平水韵的“文”韵。整体意象从宏观的春光逐步聚焦到具体的自然细节，最后落到人类活动，层次比较丰富。'} response_metadata={'token_usage': {'completion_tokens': 340, 'prompt_tokens': 11, 'total_tokens': 351, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 174, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 11}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_finger
# ...

# %% [markdown]
# ## 1.2.调用智谱AI

# %%
import os
from dotenv import load_dotenv
from langchain_community.chat_models import ChatZhipuAI

load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")


llm_zhipu = ChatZhipuAI(
    model="glm-4.5-air",
    api_key=ZHIPUAI_API_KEY,
    # api_base=ZHIPUAI_BASE_URL,
)

response = llm_zhipu.invoke("请用一句话介绍你是哪个模型")
print(response)
# Out:
# content='我是由智谱AI训练的GLM大语言模型。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 12, 'prompt_tokens_details': {'cached_tokens': 11}, 'total_tokens': 135}, 'model_name': 'glm-4.5-air', 'finish_reason': 'stop'} id='lc_run--019f0937-6b89-7540-9ff4-6652534f723f-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# # 2.模型通用调用

# %%
from langchain_openai import ChatOpenAI


load_dotenv(override=True)
ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")

model = ChatOpenAI(
    model="glm-4.5-air",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHIPUAI_BASE_URL,
)

response = model.invoke("请用一句话介绍你是哪个模型")
print(response)
# Out:
# content='我是由智谱AI训练的GLM大语言模型。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 12, 'total_tokens': 112, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 4}}, 'model_provider': 'openai', 'model_name': 'glm-4.5-air', 'system_fingerprint': None, 'id': '20260627211330024c5a955b634dd5', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f0936-ba2b-78b0-9ca1-5478b52f6bfc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 100, 'total_tokens': 112, 'input_token_details': {'cache_read': 4}, 'output_token_details': {}}

# %% [markdown]
# # 3.使用中转平台

# %% [markdown]
# ## 3.1 使用openrouter平台

# %%
import os
from dotenv import load_dotenv
from langchain_openrouter import ChatOpenRouter

load_dotenv(override=True)
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

response = model.invoke("请用一句话介绍你是哪个模型")
print(response)
# Out:
# ---------------------------------------------------------------------------
# OpenRouterDefaultError                    Traceback (most recent call last)
# Cell In[33], line 15
#      11     api_key=OPENROUTER_API_KEY,
#      12     base_url=OPENROUTER_API_BASE,
#      13 )
#      14
# ---> 15 response = model.invoke("请用一句话介绍你是哪个模型")
#      16 print(response)
#
# File /opt/anaconda3/envs/langchain1.2/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
# ...

# %% [markdown]
# ## 3.2 使用closeAI平台

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_API_BASE = os.getenv("CLOSEAI_API_BASE")

model = ChatOpenAI(
    model="o4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_API_BASE,
)

response = model.invoke("请用一句话介绍你是哪个模型")
print(response)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[3], line 15
#      11     api_key=CLOSEAI_API_KEY,
#      12     base_url=CLOSEAI_API_BASE,
#      13 )
#      14
# ---> 15 response = model.invoke("请用一句话介绍你是哪个模型")
#      16 print(response)
#
# File /opt/anaconda3/envs/langchain1.2/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
# ...

# %% [markdown]
# # 4.使用langchain1.x的统一方式调用模型

# %% [markdown]
# ## 4.1 调用智谱模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model_provider="openai",
    model="glm-4.5-air",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHIPUAI_BASE_URL,
    # temperature=0.7,
    max_tokens=10,
)

response = model.invoke("为什么在langchain的框架中没法限制你的max_tokens？")
print(response.content)
# Out:
# 在LangChain框架中，你**实际上是可以**限制`max_tokens`的！但这个问题通常源于对LangChain工作原理的误解或配置上的疏忽。以下是详细解释和解决方案：
#
# ### 🧠 核心原因：LangChain是框架，不是模型本身
#
# 1.  **LangChain的角色：** LangChain是一个**编排框架**。它提供工具、链和代理来构建复杂的应用程序，但它**不直接执行语言模型推理**。实际的文本生成是由底层的LLM（如OpenAI的GPT模型、Anthropic的Claude模型、Hugging Face模型等）完成的。
# 2.  **`max_tokens`的位置：** `max_tokens`参数是**底层LLM API**的一个核心参数，用于限制模型在单次响应中生成的最大令牌数量。LangChain通过其`LLM`或`ChatModel`类（如`OpenAI`, `ChatOpenAI`, `ChatAnthropic`等）将这些参数传递给底层的API调用。
#
# ### 🔍 为什么用户可能觉得“无法限制”？
#
# 1.  **未在正确的位置设置：**
#     *   **最常见的原因：** 用户可能在构建链或代理时，忘记在**初始化`LLM`/`ChatModel`实例**时设置`max_tokens`参数。例如：
#         ```python
#         # 错误：没有设置 max_tokens
#         llm = OpenAI()  # 或者 ChatOpenAI()
#
#         # 正确：在初始化时设置
#         llm = OpenAI(max_tokens=100)  # 或者 ChatOpenAI(max_tokens=100)
#         ```
#     *   **高级链/代理中的配置：** 在使用`LCEL`（LangChain Expression Language）链或代理时，参数通常在链的最终`LLM`调用处设置，而不是在中间步骤。如果链的末尾没有正确配置`max_tokens`，它就不会生效。
#
# 2.  **动态提示导致Token不可控：**
# ...
