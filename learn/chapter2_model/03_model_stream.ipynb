# %% [markdown]
# ## 1 stream

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model_provider="openai",
    model="glm-4.5-air",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHIPUAI_BASE_URL,
    # temperature=0.7,
    # max_tokens=10,
)

# %%
for chunk in model.stream("你好,解释什么是瓦学弟"):
    print(chunk.content, end="", flush=True)
# Out:
# “瓦学弟”是一个结合了网络流行语和粉丝文化的中文谐音梗，主要指代演员**王鹤棣**。
#
# 以下是详细解释：
#
# 1.  **“瓦”的来源：**
#     *   在中文网络用语中，“瓦”常被用作“王”的谐音。这是因为“瓦”和“王”的拼音首字母都是“W”，且在某些方言或特定语境下发音相近。
#     *   这种谐音梗在粉丝圈和网络社区中很常见，用于增加趣味性或避免直接称呼名字（有时是为了调侃或制造昵称）。
#
# 2.  **“学弟”的来源：**
#     *   王鹤棣毕业于**四川音乐学院**（流行音乐学院）。
#     *   他的粉丝群体中，尤其是女粉丝，常自称“**棣学妹**”（“棣”取自王鹤棣名字中的“棣”，“学妹”指代自己是王鹤棣的学妹）。
#     *   相应地，称呼王鹤棣本人时，粉丝或网友有时会戏称他为“**学弟**”，意指他是“棣学妹”们的学长/学弟（这里“学弟”是相对于粉丝自称的“学妹”而言的）。
#
# 3.  **“瓦学弟”的整体含义：**
#     *   将“瓦”（王）和“学弟”结合起来，“瓦学弟”就成了**王鹤棣**的一个**网络昵称**或**代称**。
#     *   它主要出现在**社交媒体（如微博、小红书、抖音等）、粉丝讨论区、弹幕、评论区**等网络环境中。
#     *   这个称呼带有**亲切感、调侃意味和粉丝文化特色**，体现了粉丝对偶像的喜爱和一种特定的圈内称呼方式。
#
# 4.  **使用场景：**
#     *   **粉丝自称/互称：** 粉丝在讨论王鹤棣时，可能会用“瓦学弟”来指代他，显得更亲近、更有趣。例如：“瓦学棣的新剧好帅！”
#     *   **路人/网友调侃：** 不熟悉粉丝圈的路人网友，在看到相关内容时，可能会模仿这种称呼方式，带有一定的调侃或跟风意味。
#     *   **内容创作：** 一些二创视频、图文、段子等，可能会使用“瓦学弟”作为标签或梗。
#
# **总结：**
#
# **“瓦学弟”就是王鹤棣的谐音昵称，由“瓦”（王）和“学弟”（相对于粉丝“棣学妹”的称呼）组合而成。它主要在粉丝圈和网络流行文化中被用来指代王鹤棣，带有亲切、调侃和粉丝专属的色彩。**
#
# 下次你在网上看到“瓦学弟”这个词，就知道大家是在谈论那位凭借《苍兰诀》等作品走红的帅气演员王鹤棣啦！

# %% [markdown]
# ## 2 批量调用 batch
